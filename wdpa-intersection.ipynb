# %% [markdown]
# # WDPA-Intersection

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import geopandas as gpd
import yaml
from pathlib import Path
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import plotly.express as px

# %% [markdown]
# ### Load Shapefiles downloaded from WDPA website

# %%
# Load config.yaml
with open("config.yaml", "r") as f:
    config = yaml.safe_load(f)

# Get base path from config
base_path = Path(config["wdpa_base_path"])

# Load the 3 individual shapefiles
WDPA_01 = gpd.read_file(base_path / "WDPA_Jun2025_Public_shp_0" / "WDPA_Jun2025_Public_shp-polygons.shp")
WDPA_02 = gpd.read_file(base_path / "WDPA_Jun2025_Public_shp_1" / "WDPA_Jun2025_Public_shp-polygons.shp")
WDPA_03 = gpd.read_file(base_path / "WDPA_Jun2025_Public_shp_2" / "WDPA_Jun2025_Public_shp-polygons.shp")

# %%
# Merge the 3 datasets
merged_wdpa = gpd.GeoDataFrame(pd.concat([WDPA_01, WDPA_02, WDPA_03], ignore_index=True))
# Project 
merged_wdpa_3857 = merged_wdpa.to_crs(epsg=3857)

# %% [markdown]
# ## Data exploration of WDPA

# %%
merged_wdpa.head(3)
# Out:
#    WDPAID WDPA_PID PA_DEF                                  NAME  \
# 0     1.0        1      1  Diamond Reef and Salt Fish Tail Reef
# 1     2.0        2      1                         Palaster Reef
# 2     3.0        3      1                Laguna de los Pozuelos
#
#                 ORIG_NAME              DESIG        DESIG_ENG DESIG_TYPE  \
# 0            Diamond Reef     Marine Reserve   Marine Reserve   National
# 1           Palaster Reef     Marine Reserve   Marine Reserve   National
# 2  Laguna de los Pozuelos  Monumento Natural  Nature Monument   National
#
#   IUCN_CAT        INT_CRIT  ...                             MANG_AUTH  \
# 0       Ia  Not Applicable  ...                    Fisheries Division
# 1       Ia  Not Applicable  ...                    Fisheries Division
# 2      III  Not Applicable  ...  Administración de Parques Nacionales
#
#       MANG_PLAN           VERIF  METADATAID  SUB_LOC PARENT_ISO  ISO3  \
# 0  Not Reported  State Verified        1807    AG-04        ATG   ATG
# 1  Not Reported  State Verified        1807    AG-10        ATG   ATG
# 2  Not Reported  State Verified        1935     AR-Y        ARG   ARG
#
#         SUPP_INFO        CONS_OBJ  \
# 0  Not Applicable  Not Applicable
# 1  Not Applicable  Not Applicable
# 2  Not Applicable  Not Applicable
#
#                                             geometry
# 0  POLYGON ((-61.82494 17.18497, -61.82497 17.184...
# 1  POLYGON ((-61.74007 17.52001, -61.77174 17.526...
# 2  POLYGON ((-65.98955 -22.47423, -65.99441 -22.4...
#
# [3 rows x 31 columns]

# %% [markdown]
# ## Load points

# %%
merged_wdpa.columns
# Out:
# Index(['WDPAID', 'WDPA_PID', 'PA_DEF', 'NAME', 'ORIG_NAME', 'DESIG',
#        'DESIG_ENG', 'DESIG_TYPE', 'IUCN_CAT', 'INT_CRIT', 'MARINE',
#        'REP_M_AREA', 'GIS_M_AREA', 'REP_AREA', 'GIS_AREA', 'NO_TAKE',
#        'NO_TK_AREA', 'STATUS', 'STATUS_YR', 'GOV_TYPE', 'OWN_TYPE',
#        'MANG_AUTH', 'MANG_PLAN', 'VERIF', 'METADATAID', 'SUB_LOC',
#        'PARENT_ISO', 'ISO3', 'SUPP_INFO', 'CONS_OBJ', 'geometry'],
#       dtype='object')

# %% [markdown]
# ### Load points

# %%
# Define sample power station locations (e.g in the Netherlands)
power_locations = {
    "Name" : ["Power Plant A", "Charging Station B", "Hydrogen Hub C", "Wind Site D", "Battery Bank E"],
    "energy_type" : ["Fossil", "Electric", "Hydrogen", "Wind", "Battery"],
    "operational": [True, True, False, True, False],
    "latitude": [52.310488, 52.093674, 51.933041, 53.221734, 51.433843],
    "longitude": [4.905643, 5.116298, 4.487232, 6.566158, 5.477312]
}
power_locations_df = pd.DataFrame(power_locations)

# Convert points to GeoDataFrame
power_locations_gdf = gpd.GeoDataFrame(
    power_locations_df,
    geometry=gpd.points_from_xy(power_locations_df.longitude, power_locations_df.latitude),
    crs="EPSG:4326"
)

# %%
# Project to meters for buffering
power_locations = power_locations_gdf.to_crs(epsg=3857)
power_locations_gdf_buffer['geometry'] = power_locations.buffer(1000)  # 10km buffer
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_43a6190d0c8a47a6cc0adc1cff14be15 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_43a6190d0c8a47a6cc0adc1cff14be15&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_43a6190d0c8a47a6cc0adc1cff14be15 = L.map(
#                 &quot;map_43a6190d0c8a47a6cc0adc1cff14be15&quot;,
#                 {
#                     center: [52.32767722632856, 5.526694999999999],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_43a6190d0c8a47a6cc0adc1cff14be15);
#
#
#
#
#
#             var tile_layer_0b1d9bc2ed3fafc475a66c7adcf0571f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0b1d9bc2ed3fafc475a66c7adcf0571f.addTo(map_43a6190d0c8a47a6cc0adc1cff14be15);
#
#
#             map_43a6190d0c8a47a6cc0adc1cff14be15.fitBounds(
#                 [[51.42824239875759, 4.478248847158803], [53.22711205389954, 6.575141152841195]],
#                 {}
#             );
#
#
#         function geo_json_bf13f6174d2a997f7a1ac771833be33c_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_bf13f6174d2a997f7a1ac771833be33c_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_bf13f6174d2a997f7a1ac771833be33c_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_bf13f6174d2a997f7a1ac771833be33c_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_bf13f6174d2a997f7a1ac771833be33c_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_bf13f6174d2a997f7a1ac771833be33c.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_bf13f6174d2a997f7a1ac771833be33c_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_bf13f6174d2a997f7a1ac771833be33c = L.geoJson(null, {
#                 onEachFeature: geo_json_bf13f6174d2a997f7a1ac771833be33c_onEachFeature,
#
#                 style: geo_json_bf13f6174d2a997f7a1ac771833be33c_styler,
#                 pointToLayer: geo_json_bf13f6174d2a997f7a1ac771833be33c_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_bf13f6174d2a997f7a1ac771833be33c_add (data) {
#             geo_json_bf13f6174d2a997f7a1ac771833be33c
#                 .addData(data);
#         }
#             geo_json_bf13f6174d2a997f7a1ac771833be33c_add({&quot;bbox&quot;: [4.478248847158803, 51.42824239875759, 6.575141152841195, 53.22711205389954], &quot;features&quot;: [{&quot;bbox&quot;: [4.896659847158805, 52.30499551957505, 4.914626152841196, 52.31597979901516], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[4.914626152841196, 52.31048799999999], [4.91458289650492, 52.309949672897616], [4.914453544078257, 52.30941652372721], [4.9142393412957865, 52.308893687285874], [4.9139423510

# %% [markdown]
# ![Map Preview](map_preview01.png)

# %% [markdown]
# ## Find intersections

# %%
# Use spatial join function from GeoPandas. It combines two GeoDataFrames based on the spatial relationship between their geometries.
intersections = gpd.sjoin(power_locations_gdf_buffer, merged_wdpa_3857, how='inner', predicate='intersects')

# %%
 # If a single point (or its buffer) intersects multiple polygons in the second GeoDataFrame, the spatial join will create one row per each intersection.
intersections
print(intersections.crs)
# Out:
#              Name energy_type  operational   latitude  longitude  \
# 0   Power Plant A      Fossil         True  52.310488   4.905643
# 4  Battery Bank E     Battery        False  51.433843   5.477312
#
#                                             geometry  index_right  \
# 0  POLYGON ((547093.681 6856461.545, 547088.866 6...       197300
# 4  POLYGON ((610731.583 6698397.313, 610726.767 6...       197303
#
#         WDPAID   WDPA_PID PA_DEF  ...      OWN_TYPE              MANG_AUTH  \
# 0  555638689.0  555638689      1  ...  Not Reported  Ministry EZ RVO/GISCC
# 4  555638692.0  555638692      1  ...  Not Reported  Ministry EZ RVO/GISCC
#
#       MANG_PLAN           VERIF METADATAID       SUB_LOC PARENT_ISO ISO3  \
# 0  Not Reported  State Verified       2013  Not Reported        NLD  NLD
# 4  Not Reported  State Verified       2013  Not Reported        NLD  NLD
#
#         SUPP_INFO        CONS_OBJ
# 0  Not Applicable  Not Applicable
# 4  Not Applicable  Not Applicable
#
# [2 rows x 37 columns]

# %% [markdown]
# ## Finds non intersections

# %%
# The spatial join (above) keeps the index from the left GeoDataFrame (shell_locations_gdf_buffer)
# intersections.index contains indices of all points that had at least one intersection
# We use ~ to invert the boolean mask, selecting only rows whose index is NOT in intersections

non_intersections = power_locations_gdf_buffer.loc[~power_locations_gdf_buffer.index.isin(intersections.index)]
print(non_intersections.crs)

# %% [markdown]
# ## Visualize outputs

# %%
# 1. Add an 'intersects' flag
intersections['intersects'] = True
non_intersections['intersects'] = False

# 2. Combine into a single GeoDataFrame
combined = pd.concat([intersections, non_intersections])

# 3. Plot with different colors based on 'intersects'
color_map = {True: 'red', False: 'purple'}
combined.explore(color=combined['intersects'].map(color_map), alpha=1)
# Out:
# /Users/olgavalenti/Workspace/gis/wdpa-intersection/venv/lib/python3.13/site-packages/geopandas/geodataframe.py:1968: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d279c5d5388239dd80d0f7cf1ff151d4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d279c5d5388239dd80d0f7cf1ff151d4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d279c5d5388239dd80d0f7cf1ff151d4 = L.map(
#                 &quot;map_d279c5d5388239dd80d0f7cf1ff151d4&quot;,
#                 {
#                     center: [52.32767722632856, 5.526694999999999],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_d279c5d5388239dd80d0f7cf1ff151d4);
#
#
#
#
#
#             var tile_layer_2b7a51f7157bbd36857ecdf2bdee80f5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2b7a51f7157bbd36857ecdf2bdee80f5.addTo(map_d279c5d5388239dd80d0f7cf1ff151d4);
#
#
#             map_d279c5d5388239dd80d0f7cf1ff151d4.fitBounds(
#                 [[51.42824239875759, 4.478248847158803], [53.22711205389954, 6.575141152841195]],
#                 {}
#             );
#
#
#         function geo_json_89ef21d668a821ec0227ad44de371147_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;4&quot;:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;purple&quot;, &quot;fillColor&quot;: &quot;purple&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_89ef21d668a821ec0227ad44de371147_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_89ef21d668a821ec0227ad44de371147_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_89ef21d668a821ec0227ad44de371147_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_89ef21d668a821ec0227ad44de371147_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_89ef21d668a821ec0227ad44de371147.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_89ef21d668a821ec0227ad44de371147_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_89ef21d668a821ec0227ad44de371147 = L.geoJson(null, {
#                 onEachFeature: geo_json_89ef21d668a821ec0227ad44de371147_onEachFeature,
#
#                 style: geo_json_89ef21d668a821ec0227ad44de371147_styler,
#                 pointToLayer: geo_json_89ef21d668a821ec0227ad44de371147_pointToLayer,
#             ...{
#   &quot;alpha&quot;: 1,
# }
#         });
#
#         function geo_json_89ef21d668a821ec0227ad44de371147_add (data) {
#             geo_json_89ef21d668a821ec0227ad44de371147
#                 .addData(data);
#         }
#             geo_json_89ef21d668a821ec0227ad44de371147_add({&quot;bbox&quot;: [4.478248847158803, 51.42824239875759, 6.575141152841195, 53.22711205389954], &quot;features&quot;: [{

# %% [markdown]
# ![Map Preview](map_preview02.png)
